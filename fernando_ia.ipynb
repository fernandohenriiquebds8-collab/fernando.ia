# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandohenriiquebds8-collab/fernando.ia/blob/main/fernando_ia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎭 Fernando IA - Manipulação Facial Pro
# Este notebook configura o ambiente do FaceFusion para você usar gratuitamente no Google Colab.
#
# ### 💡 Instruções:
# 1. Clique em **Ambiente de execução** > **Alterar tipo de ambiente de execução** e escolha **T4 GPU**.
# 2. Execute a primeira célula para instalar tudo.
# 3. Execute a segunda para iniciar a interface.

# %%
# @title 🚀 Passo 1: Instalação Automática
# Limpando vestígios anteriores para evitar erros de pasta já existente
# !rm -rf /content/fernando.ia

# Baixando os arquivos base do seu repositório
# !git clone https://github.com/fernandohenriiquebds8-collab/fernando.ia
# %cd /content/fernando.ia

# Caso a pasta facefusion esteja faltando, baixamos a oficial automaticamente
import os
if not os.path.exists('facefusion'):
    print("📦 Recuperando componentes de IA essenciais...")
    # !git clone https://github.com/facefusion/facefusion temp_ff
    # !cp -r temp_ff/facefusion ./
    # !rm -rf temp_ff

# Instalando bibliotecas sem build-isolation para evitar erros do Python 3.12 no Colab
# !pip install --no-build-isolation onnxruntime-gpu gradio opencv-python numpy pillow insightface==0.7.3 tqdm colorlog filetype

# Tentamos rodar a instalação oficial, mas se der erro prosseguimos pois já instalamos o core acima
# !python install.py --processor cuda --skip-venv || echo "Finalizado com avisos do sistema."

# %%
# @title 🎨 Passo 2: Iniciar Interface
# %cd /content/fernando.ia
# !python facefusion.py run --share
