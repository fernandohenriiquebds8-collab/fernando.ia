# %% [markdown]
# # 🎭 Fernando IA - VERSÃO GOOGLE DRIVE (SIMPLIFICADA)
# Esta versão guarda tudo no seu Drive para você nunca mais ter que configurar nada!
#
# ### 💡 Como usar:
# 1. No Colab, vá em **Ambiente de execução** > **Alterar tipo** e escolha **GPU T4**.
# 2. Execute o **Passo 1** (Ele vai pedir permissão para acessar o seu Drive - é seguro!).
# 3. Execute o **Passo 2** e abra o link azul.

# %%
# @title 🚀 Passo 1: Conectar Drive e Instalar
from google.colab import drive
drive.mount('/content/drive')

# Criando a pasta do projeto no Drive
import os
path = "/content/drive/MyDrive/FernandoIA"
if not os.path.exists(path):
    os.makedirs(path)
    # %cd $path
    # !git clone https://github.com/facefusion/facefusion
else:
    print("✅ Pasta do projeto já existe no seu Drive!")

# %cd $path/facefusion

# Instalando bibliotecas rápidas
# !pip install onnxruntime-gpu gradio opencv-python numpy pillow insightface==0.7.3 tqdm colorlog filetype
# !python install.py --processor cuda --skip-venv

# %%
# @title 🎨 Passo 2: Iniciar Sistema
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/FernandoIA/facefusion
# %env GRADIO_SHARE=true
# !python facefusion.py run
